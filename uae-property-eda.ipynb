# %%
import pandas as pd
import matplotlib as plt

# %%
df  = pd.read_csv('D:\project-csv\Transactions_updated (1).csv')

# %%
df.head()
# Out:
#    Unnamed: 0    transaction_id  procedure_id  trans_group_id trans_group_en  \
# 0           0    1-11-2004-2099            11               1          Sales
# 1           1   1-11-2010-15769            11               1          Sales
# 2           2  1-11-2008-211116            11               1          Sales
# 3           3    1-11-2010-3056            11               1          Sales
# 4           4  1-11-2009-214345            11               1          Sales
#
#   procedure_name_en instance_date  property_type_id property_type_en  \
# 0              Sell    04-10-2004                 4            Villa
# 1              Sell    25-10-2010                 3             Unit
# 2              Sell    18-12-2008                 3             Unit
# 3              Sell    10-03-2010                 3             Unit
# 4              Sell    20-07-2009                 3             Unit
#
#    property_sub_type_id  ... rooms_en has_parking  procedure_area  \
# ...

# %%
df.groupby('trans_group_en')['trans_group_en'].agg('count')
# Out:
# trans_group_en
# Gifts         38565
# Mortgages    234682
# Sales        838774
# Name: trans_group_en, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'transaction_id', 'procedure_id', 'trans_group_id',
#        'trans_group_en', 'procedure_name_en', 'instance_date',
#        'property_type_id', 'property_type_en', 'property_sub_type_id',
#        'property_sub_type_en', 'property_usage_en', 'reg_type_id',
#        'reg_type_en', 'area_id', 'area_name_en', 'building_name_en',
#        'project_number', 'project_name_en', 'master_project_en',
#        'nearest_landmark_en', 'nearest_metro_en', 'nearest_mall_en',
#        'rooms_en', 'has_parking', 'procedure_area', 'actual_worth',
#        'meter_sale_price', 'rent_value', 'meter_rent_price',
#        'no_of_parties_role_1', 'no_of_parties_role_2', 'no_of_parties_role_3'],
#       dtype='object')

# %%
df = df.drop(columns = [col for col in df.columns if col.endswith('id')])

# %%
df = df.drop(columns = )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112021 entries, 0 to 1112020
# Data columns (total 26 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Unnamed: 0            1112021 non-null  int64
#  1   trans_group_en        1112021 non-null  object
#  2   procedure_name_en     1112021 non-null  object
#  3   instance_date         1112021 non-null  object
#  4   property_type_en      1112021 non-null  object
#  5   property_sub_type_en  860706 non-null   object
#  6   property_usage_en     1112021 non-null  object
#  7   reg_type_en           1112021 non-null  object
#  8   area_name_en          1112021 non-null  object
#  9   building_name_en      767804 non-null   object
#  10  project_number        709689 non-null   float64
#  11  project_name_en       709689 non-null   object
#  12  master_project_en     913777 non-null   object
#  13  nearest_landmark_en   971098 non-null   object
# ...

# %%
df1 = df['actual_worth','nearest_landmark_en','rooms_en','has_parking','procedure_area']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sarim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\sarim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\sarim\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 trans_group_en          procedure_name_en instance_date  \
# 0           0          Sales                       Sell    04-10-2004
# 1           1          Sales                       Sell    25-10-2010
# 2           2          Sales                       Sell    18-12-2008
# 3           3          Sales                       Sell    10-03-2010
# 4           4          Sales                       Sell    20-07-2009
# 5           5          Sales  Lease to Own Registration    16-06-2014
# 6           6      Mortgages      Mortgage Registration    14-04-2014
# 7           7          Sales    Sell - Pre registration    10-02-2015
# 8           8          Sales    Sell - Pre registration    14-05-2010
# 9           9          Sales               Delayed Sell    02-07-2015
#
#   property_type_en property_sub_type_en property_usage_en  \
# 0            Villa                  NaN        Commercial
# 1             Unit                 Flat       Residential
# ...
